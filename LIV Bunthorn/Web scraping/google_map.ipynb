# %%
import pandas as pd

df = pd.read_csv('google_place_dataset/kampot.csv')
df = df.iloc[1: , :]
df = pd.DataFrame(df)
df
# Out:
#                                                   map  \
# 1   https://www.google.com/maps/place/Durian+Round...
# 2   https://www.google.com/maps/place/Bokor+Hill+S...
# 3   https://www.google.com/maps/place/Kampot+River...
# 4   https://www.google.com/maps/place/New+Kampot+R...
# 5   https://www.google.com/maps/place/Veal+Pouch+W...
# ..                                                ...
# 62  https://www.google.com/maps/place/Inthanou+Bou...
# 63  https://www.google.com/maps/place/Sopheak+Mong...
# 64  https://www.google.com/maps/place/The+Apartmen...
# 65  https://www.google.com/maps/place/%E1%9E%95%E1...
# 66  https://www.google.com/maps/place/Kampot+Relax...
#
#                             place  review rate reviewer       type of place  \
# 1               Durian Roundabout          4.2  (2,354)  Tourist attraction
# 2              Bokor Hill Station          4.3  (1,820)  Tourist attraction
# 3   Kampot River Motorcycle Tours          NaN      NaN  Tourist attraction
# ...

# %%
df = pd.read_csv('google_place_dataset/kep.csv')
df = df.iloc[1: , :]
df = pd.DataFrame(df)
df
# Out:
#                                                                                                                                                                                                        map  \
# 1                       https://www.google.com/maps/place/Kep+National+Park/data=!4m6!3m5!1s0x3109cd4f100c579d:0x97421e5b313c4e24!8m2!3d10.4920228!4d104.2998423!16s%2Fm%2F05p6lsn?authuser=0&hl=en&rclk=1
# 2   https://www.google.com/maps/place/Krung+Kep+Blue+Swimmer+Crab+Statue/data=!4m6!3m5!1s0x3109cd59b76bdba5:0xea3bbe93d23997a6!8m2!3d10.4762756!4d104.2994548!16s%2Fg%2F11c1wjdqk3?authuser=0&hl=en&rclk=1
# 3                   https://www.google.com/maps/place/Wat+Samathi+Pagoda/data=!4m6!3m5!1s0x3109cd160d8b7a91:0x50c115e7d06c65f6!8m2!3d10.5000291!4d104.3137918!16s%2Fg%2F11bc6q0q7g?authuser=0&hl=en&rclk=1
# ...
