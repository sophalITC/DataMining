# %% [markdown]
# # Name: Huon Sophy
# # ID: M060809
# # <center> Scrape Bicycles from Khmer24 using BeautifulSoup </center>
#
# ### What is Web Scraping?
# <p style="font-family: Times New Roman, serif; font-size:16pt; line-height: 1.5;">
#      &nbsp <b>Web scraping</b> is the process of gathering information from the Internet. However, the words “web scraping” usually refer to a process that involves automation.
# </p>
#
# ### What is Beautiful Soup?
# <p style="font-family: Times New Roman, serif; font-size:16pt; line-height: 1.5;">
#     &nbsp </b>Beautiful Soup</b> is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.
# </p>

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as soup
import pandas as pd

# %% [markdown]
# ## HTTP Request
# <p style="font-family: Times New Roman, serif; font-size:16pt; line-height: 1.5;">
#     Store website in variable
# </p>

# %%
url = 'https://www.khmer24.com/en/c-bicycles.html'
req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})

webpage = urlopen(req).read()
page_soup = soup(webpage, "html.parser")

# %%
# display html of the bicycles page
# page_soup

# %% [markdown]
# <p style="font-family: Times New Roman, serif; font-size:16pt; line-height: 1.5;">
#     <b> Find area that we want to scrape the information. </b>
# </p>

# %%
results = page_soup.findAll('div', class_ = 'item-detail')

# %%
results[0]
# Out:
# <div class="item-detail">
# <h2 class="item-title truncate truncate-2">TREK Frame Original</h2>
# <p class="description truncate truncate-2">TREK Frame
# #ហាងកង់ចាក់អង្រែ
# &gt; មានលក់កង់ជជុស​ជប៉ុន​​ និងកង់ថ្មីម៉ាក UPLAND DIAMON និង​ TRINX
# &gt; មានសេវា <i>tel: 092510051</i></p> <ul class="list-unstyled summary">
# <li>Phnom Penh</li>
# <li><time datetime="2022-07-06 10:00:02">7 minutes ago</time></li>
# <li>1 hits</li> </ul>
# <p class="item-prices m-0 text-red"><span class="price">$195</span></p>
# </div>

# %%
len(results)
# Out:
# 50

# %% [markdown]
# <p style="font-family: Times New Roman, serif; font-size:16pt; line-height: 1.5;">
#     <b> Get Title, Descrioption, Location, and Price. </b>
# </p>

# %%
results[0].find('h2', {'class':'item-title'}).get_text()
# Out:
# 'TREK Frame Original'

# %%
results[0].find('p', {'class':'description truncate truncate-2'}).get_text().strip()
# Out:
# 'TREK Frame\n#ហាងកង់ចាក់អង្រែ\n> មានលក់កង់ជជុស\u200bជប៉ុន\u200b\u200b និងកង់ថ្មីម៉ាក UPLAND DIAMON និង\u200b TRINX\n> មានសេវា tel: 092510051'

# %%
results[0].find('p', {'class':'description truncate truncate-2'}).find('i').get_text()
# Out:
# 'tel: 092510051'

# %%
results[0]('ul', {'class':'list-unstyled summary'})
# Out:
# [<ul class="list-unstyled summary">
#  <li>Phnom Penh</li>
#  <li><time datetime="2022-07-06 10:00:02">7 minutes ago</time></li>
#  <li>1 hits</li> </ul>]

# %%
results[0].find('li').get_text()
# Out:
# 'Phnom Penh'

# %%
results[0].find('span', {'class':'price'}).get_text()
# Out:
# '$195'

# %% [markdown]
# <p style="font-family: Times New Roman, serif; font-size:16pt; line-height: 1.5;">
#     <b> Put Title, Descrioption, Location, and Price inside the Loop. </b>
# </p>

# %%
# Get Title, Descrioption, Location, and Price

title = []
description = []
phone = []
location = []
price = []

for result in results:
    
    try:
        title.append(result.find('h2', {'class':'item-title'}).get_text())
    except:
        title.append('n/a')
    try:
        description.append(result.find('p', {'class':'description truncate truncate-2'}).get_text().strip('\n'))
    except:
        description.append('n/a')
    try:
        phone.append(result.find('p', {'class':'description truncate truncate-2'}).find('i').get_text())
    except:
        phone.append('n/a')
    try:
        location.append(result.find('li').get_text())
    except:
        location.append('n/a')
    try:
        price.append(result.find('span', {'class':'price'}).get_text())
    except:
        price.append('n/a')

# %%
title
# Out:
# ['TREK Frame Original',
#  'Scott scale 970',
#  'កង់លក់ Scott sub',
#  'Scott gravel',
#  'Scott',
#  'TRINX',
#  'ពិលកង់ 800lumen ( fast charger )',
#  'Cannondale F300',
#  'Panasonic MR-S vintage ( classic)',
#  'Groupset SRAM SX',
#  'Trek Malin 5 2022 99% 3 Times used.',
#  '2022 Trek Malin 5 S27.5 99%',
#  'ជជុះជប៉ុនរង្វង់27.5 នៅខ្មែរមិនទាន់ជិះ',
#  'Wheetset 29er',
#  'ជជុះជប៉ុនរង្វង់27.5នៅខ្មែរមិនទាន់ជិះ',
#  'កង់សម្រាប់ជិះហាត់ប្រាណ រង្វង់កង់លេខ 26\u200b ៉',
#  'កង់លក់',
#  'Giant Talon 1 2021 for sale',
#  'Specialized Epic Expert 2021 New',
#  'Santacruz លក់\u200b',
#  'SantaCruz លក់\u200b 99%',
#  'Giant Rincon លក់ប្រញាប់',
#  'Forever Brand',
#  'សួរស្តី',
#  'All 10$',
#  'កង់បុរាណ លកតែ 180$',
#  'កង់បុរាណ លកតែ 180$',
#  'បញ្ចុះតម្លៃពិសេសពិលក្រោយកង់មានសុីញ៉ូប្រើតេលេបញ្ជាមានសំលេង ( Wireless remote control turn signal With horn)',
#  'កង់លក់ canondle ទើបដូរដុំបាដាងហើយ នៅថ្មី',
#  'កង់លក់ cannondle Tril5 សាយ Lអាស៊ី កង់នៅថ្មីណាស់ទើបដូរជង្គង់ប្រហោង និងបាដាងARC 009 ហើយ',
#  'SRAM SX 12',
#  'នៅថ្មីអត់ដែលជិះ រង្វង់29 150$',
#  'GIANT Revel 160$',
#  'លក់កង់ Araya',
#  'Stem',
#  'Trek malin 6️⃣',
#  'ព្យាបាល',
#  'កង់លក់បន្ទាន់ខ្វះខាតលុយទើបជិះបាន១ខែជាង',
#  'Giant Reign Sx',
#  'ទួអាលុយមីញ៉ូម លេខ មុខ 3 ក្រោយ 9',
#  'Giant XTC SLR 2 (2021)',
#  'Giant XTC SLR 2 (2021)',
#  'Specialize',
#  'Specialized From usa',
#  'កង់លក់',
#  'កង់ជប៉ុន បូមមុខក្រោយមានច្រើនoption off road',
#  'លក់ឡៃឡុងYETI',
#  'KTM',
#  'កង់ លក់ 230$',
#  'Specialized 95% for sale']

# %% [markdown]
# ## Create Dataframe

# %%
bicycle_data = pd.DataFrame({'Title': title, 'Description': description, 'Phone': phone, 'Location': location, 'Price': price})

# %%
bicycle_data
# Out:
#                                                 Title  \
# 0                                 TREK Frame Original
# 1                                     Scott scale 970
# 2                                    កង់លក់ Scott sub
# 3                                        Scott gravel
# 4                                               Scott
# 5                                               TRINX
# 6                    ពិលកង់ 800lumen ( fast charger )
# 7                                     Cannondale F300
# 8                   Panasonic MR-S vintage ( classic)
# 9                                    Groupset SRAM SX
# 10                Trek Malin 5 2022 99% 3 Times used.
# 11                        2022 Trek Malin 5 S27.5 99%
# 12              ជជុះជប៉ុនរង្វង់27.5 នៅខ្មែរមិនទាន់ជិះ
# 13                                      Wheetset 29er
# 14               ជជុះជប៉ុនរង្វង់27.5នៅខ្មែរមិនទាន់ជិះ
# 15          កង់សម្រាប់ជិះហាត់ប្រាណ រង្វង់កង់លេខ 26​ ៉
# 16                                             កង់លក់
# 17                        Giant Talon 1 2021 for sale
# 18                   Specialized Epic Expert 2021 New
# 19                                     Santacruz លក់​
# 20                                 SantaCruz លក់​ 99%
# 21                            Giant Rincon លក់ប្រញាប់
# 22                                      Forever Brand
# 23                                            សួរស្តី
# 24                                            All 10$
# 25                                 កង់បុរាណ លកតែ 180$
# 26                                 កង់បុរាណ លកតែ 180$
# 27  បញ្ចុះតម្លៃពិសេសពិលក្រោយកង់មានសុីញ៉ូប្រើតេលេបញ...
# 28           កង់លក់ canondle ទើបដូរដុំបាដាងហើយ នៅថ្មី
# 29  កង់លក់ cannondle Tril5 សាយ Lអាស៊ី កង់នៅថ្មីណាស...
# 30                                         SRAM SX 12
# 31                      នៅថ្មីអត់ដែលជិះ រង្វង់29 150$
# 32                                   GIANT Revel 160$
# 33                                       លក់កង់ Araya
# 34                                               Stem
# 35                                     Trek malin 6️⃣
# 36                                            ព្យាបាល
# 37             កង់លក់បន្ទាន់ខ្វះខាតលុយទើបជិះបាន១ខែជាង
# 38                                     Giant Reign Sx
# 39                    ទួអាលុយមីញ៉ូម លេខ មុខ 3 ក្រោយ 9
# 40                             Giant XTC SLR 2 (2021)
# 41                             Giant XTC SLR 2 (2021)
# 42                                         Specialize
# 43                               Specialized From usa
# 44                                             កង់លក់
# 45        កង់ជប៉ុន បូមមុខក្រោយមានច្រើនoption off road
# 46                                       លក់ឡៃឡុងYETI
# 47                                                KTM
# 48                                       កង់ លក់ 230$
# 49                           Specialized 95% for sale
#
#                                           Description  \
# 0   TREK Frame\n#ហាងកង់ចាក់អង្រែ\n> មានលក់កង់ជជុស​...
# 1   Sram SX 12លេខ ប៉ូម rockshok judy ប្រាំង Mt200 ...
# 2   កង់លក់ Scott sub M 27.5 គ្រឿង Sram X7 កង់ជុលជុ...
# 3   Scott gravel 700 X 35 9លេខ ជង្គង់ប៉ាដាង single...
# 4   Scott sub សេះស គ្រឿង sram X7 ជង្គង់ប៉ាដាងជើងប៉...
# 5   កង់ស្អាតគ្រឿង shimano Altus M2000 ប្រាំង ប្រេង...
# 6   🚴‍♂️ ពិលមូល #Rockbros 800lm ( fast charger )\n...
# 7                           010 545774 tel: 010545774
# 8   Shimano Deore DX (3x7) រង្វង់ កង់ 26 tel: 0105...
# 9   ធ្លាប់តែប្រើ #លីប #ដេរីយ័រ #ដៃចុច និង #ច្រវ៉ាក...
# 10  450$ 99% Size S 27.5.\nTrek Malin 5 2022 tel: ...
# 11  តម្លៃ​ពិសេស​។ កង់​ថ្មី​ 99.99​ តម្លៃ​ខាង​លេី​អ...
# 12  ទឹកថ្នាំស៊ីនអត់ស្ងោរដូរពណ៌នៅខ្មែរមិនទាន់ជិះលិប...
# 13  Wheelset\n29er\nHub ARC for Shimano Microspin ...
# 14  ទឹកថ្នាំស៊ីនអត់ស្ងោរដូរពណ៌នៅខ្មែរមិនទាន់ជិះលិប...
# 15  Brand:BEGASSO\nSize :Small\nColor:Blue\nFrame ...
# 16      លីបនៅល្អប្រើបាន កង់ធូរស្រួលជិះ tel: 099923266
# 17  Frame:\nColour: Desert Sage\nFrame: ALUXX grad...
# 18  Specialized Epic Expert 2021 New\nSize:M 29\n$...
# 19  Santacruz Bronson 2021 តួរ​កាបោន​ Size M 27/5\...
# 20  Santacruz Bronson 2021 តួរ​កាបោន​ Size M 27/5\...
# 21  កង់ Giant នៅថ្មីខ្លាំង\nមានឈ្នាន់​ ទ្រនាប់កែប​...
# 22                          រង្វង់ 26, tel: 078429973
# 23  កង់តនៅថ្មី100%អាចតប្រេីជាកង់ធំ រឹងមាំ\nគុណភាពល...
# 24  All for 10$ កាលទិញ ពី decathlon ជិត 40$ tel: 0...
# 25  កង់បុរាណ លកតែ 180$\n180$\nTelegram 099 984 901...
# 26                  កង់បុរាណ លកតែ 180$ tel: 099984901
# 27  Smart remote control turn signal USB charging ...
# 28  កង់លក់ canondle ទើបដូរដុំបាដាងហើយ នៅថ្មី tel: ...
# 29  កង់លក់ cannondle សាយ Lអាស៊ី កង់នៅថ្មីណាស់ទើបដូ...
# 30  Groupset SX\nលីប 12លេខ\nច្រវ៉ាក់ 12លេខ\nដេរីយ័...
# 31          ទិញមកអត់ដែលជិះទេ tel: 068989829,017371535
# 32  Giant revel 160$ កង់ភ្នំ នៅស្អាតជិះស្រួល\n0865...
# 33                  នៅល្អស្រួលជិះណាស់ tel: 0962230090
# 34           Stem -12°\n31.8*50mm\n99% tel: 010227519
# 35  Trek marlin 6 2021\nSize M 29.20\nSingle Speed...
# 36                  Giant is very good tel: 010689339
# 37  ម៉ាកTwitter ផលិតពីកាបូនសុទ្ធ ទម្ងន់ស្រាល 10kg ...
# 38  Hello\n- giant reign SX 2021\n- Condition. 99%...
# 39  កង់ទិញថ្មីនៅស្អាតធានាទាំងអស់តែងហើយ\nភ្លើងមុខក្...
# 40  https://www.facebook.com/111031863948940/posts...
# 41  🔥Brand New Giant XTC SLR 2 2021\nថ្មី 100%\n(N...
# 42  💡 មានចំណាប់អារម្មណ៍សូមទំនាក់ទំនង :\n☎️092 7111...
# 43  Specialized From usa\n☎️092/093 711181 tel: 01...
# 44  កង់លក់ size: L; 29inch\nគ្រឿងWL-TWoo 1x11\nបូម...
# 45  សួស្ដីបងៗ​\nអតិថិជនទាំងអស់ដែលផ្តោតសំខាន់ទៅលើទី...
# 46  កង់មួយទឹក\r(មិនទាន់ប្រើស្រុកខ្មែរ)\n(ទិញលុយសុទ...
# 47  កង់មួយទឹក\n(ទិញលុយសុទ្ធ ឬបង់រំលោះ100%)\nKTM\nS...
# 48  កង់ថ្មី ណាស់ មិនសូវដែលជិះ ថ្មីដូចបកកេស\nទើបតែថ...
# 49                      ស្រាល ស្រួលជិះ tel: 085999947
#
#                                   Phone          Location    Price
# 0                        tel: 092510051        Phnom Penh     $195
# 1             tel: 0965159022,078971799        Phnom Penh     $930
# 2             tel: 0965159022,078971799        Phnom Penh     $300
# 3             tel: 0965159022,078971799        Phnom Penh     $400
# 4             tel: 0965159022,078971799        Phnom Penh     $400
# 5             tel: 0965159022,078971799        Phnom Penh     $300
# 6             tel: 0962322777,011232277        Phnom Penh   $17.85
# 7                        tel: 010545774        Phnom Penh     $420
# 8                        tel: 010545774        Phnom Penh     $195
# 9                        tel: 092510051        Phnom Penh     $165
# 10                       tel: 089992249        Phnom Penh     $450
# 11                       tel: 089992249        Phnom Penh     $450
# 12            tel: 0965556005,090648865        Phnom Penh     $225
# 13                       tel: 092510051        Phnom Penh     $150
# 14            tel: 0965556005,090648865        Phnom Penh     $225
# 15             tel: 012334510,016334511        Phnom Penh     $155
# 16                       tel: 099923266        Phnom Penh      $55
# 17                       tel: 069532828        Phnom Penh     $529
# 18                       tel: 016360029        Phnom Penh       $6
# 19                       tel: 010666012        Phnom Penh       $4
# 20                       tel: 010666012        Phnom Penh   $4,300
# 21            tel: 0966773776,085333103        Phnom Penh     $340
# 22                       tel: 078429973        Phnom Penh     $130
# 23             tel: 012919188,068318318        Phnom Penh     $155
# 24                       tel: 099984901        Phnom Penh      $10
# 25                       tel: 099984901        Phnom Penh     $180
# 26                       tel: 099984901        Phnom Penh     $180
# 27                       tel: 010688067        Phnom Penh      $13
# 28  tel: 0962313131,0766660001,03141...        Phnom Penh     $990
# 29  tel: 0962313131,0766660001,03141...        Phnom Penh     $750
# 30                       tel: 092510051        Phnom Penh     $165
# 31             tel: 068989829,017371535        Phnom Penh     $150
# 32                       tel: 086513331         Siem Reap     $160
# 33                      tel: 0962230090        Phnom Penh     $150
# 34                       tel: 010227519        Phnom Penh      $10
# 35                       tel: 010227519        Phnom Penh     $440
# 36                       tel: 010689339        Phnom Penh     $100
# 37             tel: 086407771,066611181        Phnom Penh     $690
# 38             tel: 060679679,077679679        Phnom Penh   $2,050
# 39             tel: 087448044,085448044      Kampong Speu     $200
# 40            tel: 0965848017,017485348        Phnom Penh   $1,120
# 41            tel: 0965848017,017485348        Phnom Penh   $1,120
# 42  tel: 016493030,092711181,0937111...        Phnom Penh   $2,150
# 43  tel: 016493030,092711181,0937111...        Phnom Penh   $1,999
# 44             tel: 093999055,067555506        Phnom Penh     $300
# 45                       tel: 093688846        Phnom Penh  $390.00
# 46                       tel: 012879091        Phnom Penh   $2,500
# 47                       tel: 012879091        Phnom Penh       $1
# 48             tel: 016786478,092207092  Banteay Meanchey     $230
# 49                       tel: 085999947        Phnom Penh   $1,900

# %% [markdown]
# ## Cleaning Data for first page

# %%
bicycle_data['Phone'] = bicycle_data['Phone'].apply(lambda x:x.strip('tel:'))

bicycle_data
# Out:
#                                                 Title  \
# 0                                 TREK Frame Original
# 1                                     Scott scale 970
# 2                                    កង់លក់ Scott sub
# 3                                        Scott gravel
# 4                                               Scott
# 5                                               TRINX
# 6                    ពិលកង់ 800lumen ( fast charger )
# 7                                     Cannondale F300
# 8                   Panasonic MR-S vintage ( classic)
# 9                                    Groupset SRAM SX
# 10                Trek Malin 5 2022 99% 3 Times used.
# 11                        2022 Trek Malin 5 S27.5 99%
# 12              ជជុះជប៉ុនរង្វង់27.5 នៅខ្មែរមិនទាន់ជិះ
# 13                                      Wheetset 29er
# 14               ជជុះជប៉ុនរង្វង់27.5នៅខ្មែរមិនទាន់ជិះ
# 15          កង់សម្រាប់ជិះហាត់ប្រាណ រង្វង់កង់លេខ 26​ ៉
# 16                                             កង់លក់
# 17                        Giant Talon 1 2021 for sale
# 18                   Specialized Epic Expert 2021 New
# 19                                     Santacruz លក់​
# 20                                 SantaCruz លក់​ 99%
# 21                            Giant Rincon លក់ប្រញាប់
# 22                                      Forever Brand
# 23                                            សួរស្តី
# 24                                            All 10$
# 25                                 កង់បុរាណ លកតែ 180$
# 26                                 កង់បុរាណ លកតែ 180$
# 27  បញ្ចុះតម្លៃពិសេសពិលក្រោយកង់មានសុីញ៉ូប្រើតេលេបញ...
# 28           កង់លក់ canondle ទើបដូរដុំបាដាងហើយ នៅថ្មី
# 29  កង់លក់ cannondle Tril5 សាយ Lអាស៊ី កង់នៅថ្មីណាស...
# 30                                         SRAM SX 12
# 31                      នៅថ្មីអត់ដែលជិះ រង្វង់29 150$
# 32                                   GIANT Revel 160$
# 33                                       លក់កង់ Araya
# 34                                               Stem
# 35                                     Trek malin 6️⃣
# 36                                            ព្យាបាល
# 37             កង់លក់បន្ទាន់ខ្វះខាតលុយទើបជិះបាន១ខែជាង
# 38                                     Giant Reign Sx
# 39                    ទួអាលុយមីញ៉ូម លេខ មុខ 3 ក្រោយ 9
# 40                             Giant XTC SLR 2 (2021)
# 41                             Giant XTC SLR 2 (2021)
# 42                                         Specialize
# 43                               Specialized From usa
# 44                                             កង់លក់
# 45        កង់ជប៉ុន បូមមុខក្រោយមានច្រើនoption off road
# 46                                       លក់ឡៃឡុងYETI
# 47                                                KTM
# 48                                       កង់ លក់ 230$
# 49                           Specialized 95% for sale
#
#                                           Description  \
# 0   TREK Frame\n#ហាងកង់ចាក់អង្រែ\n> មានលក់កង់ជជុស​...
# 1   Sram SX 12លេខ ប៉ូម rockshok judy ប្រាំង Mt200 ...
# 2   កង់លក់ Scott sub M 27.5 គ្រឿង Sram X7 កង់ជុលជុ...
# 3   Scott gravel 700 X 35 9លេខ ជង្គង់ប៉ាដាង single...
# 4   Scott sub សេះស គ្រឿង sram X7 ជង្គង់ប៉ាដាងជើងប៉...
# 5   កង់ស្អាតគ្រឿង shimano Altus M2000 ប្រាំង ប្រេង...
# 6   🚴‍♂️ ពិលមូល #Rockbros 800lm ( fast charger )\n...
# 7                           010 545774 tel: 010545774
# 8   Shimano Deore DX (3x7) រង្វង់ កង់ 26 tel: 0105...
# 9   ធ្លាប់តែប្រើ #លីប #ដេរីយ័រ #ដៃចុច និង #ច្រវ៉ាក...
# 10  450$ 99% Size S 27.5.\nTrek Malin 5 2022 tel: ...
# 11  តម្លៃ​ពិសេស​។ កង់​ថ្មី​ 99.99​ តម្លៃ​ខាង​លេី​អ...
# 12  ទឹកថ្នាំស៊ីនអត់ស្ងោរដូរពណ៌នៅខ្មែរមិនទាន់ជិះលិប...
# 13  Wheelset\n29er\nHub ARC for Shimano Microspin ...
# 14  ទឹកថ្នាំស៊ីនអត់ស្ងោរដូរពណ៌នៅខ្មែរមិនទាន់ជិះលិប...
# 15  Brand:BEGASSO\nSize :Small\nColor:Blue\nFrame ...
# 16      លីបនៅល្អប្រើបាន កង់ធូរស្រួលជិះ tel: 099923266
# 17  Frame:\nColour: Desert Sage\nFrame: ALUXX grad...
# 18  Specialized Epic Expert 2021 New\nSize:M 29\n$...
# 19  Santacruz Bronson 2021 តួរ​កាបោន​ Size M 27/5\...
# 20  Santacruz Bronson 2021 តួរ​កាបោន​ Size M 27/5\...
# 21  កង់ Giant នៅថ្មីខ្លាំង\nមានឈ្នាន់​ ទ្រនាប់កែប​...
# 22                          រង្វង់ 26, tel: 078429973
# 23  កង់តនៅថ្មី100%អាចតប្រេីជាកង់ធំ រឹងមាំ\nគុណភាពល...
# 24  All for 10$ កាលទិញ ពី decathlon ជិត 40$ tel: 0...
# 25  កង់បុរាណ លកតែ 180$\n180$\nTelegram 099 984 901...
# 26                  កង់បុរាណ លកតែ 180$ tel: 099984901
# 27  Smart remote control turn signal USB charging ...
# 28  កង់លក់ canondle ទើបដូរដុំបាដាងហើយ នៅថ្មី tel: ...
# 29  កង់លក់ cannondle សាយ Lអាស៊ី កង់នៅថ្មីណាស់ទើបដូ...
# 30  Groupset SX\nលីប 12លេខ\nច្រវ៉ាក់ 12លេខ\nដេរីយ័...
# 31          ទិញមកអត់ដែលជិះទេ tel: 068989829,017371535
# 32  Giant revel 160$ កង់ភ្នំ នៅស្អាតជិះស្រួល\n0865...
# 33                  នៅល្អស្រួលជិះណាស់ tel: 0962230090
# 34           Stem -12°\n31.8*50mm\n99% tel: 010227519
# 35  Trek marlin 6 2021\nSize M 29.20\nSingle Speed...
# 36                  Giant is very good tel: 010689339
# 37  ម៉ាកTwitter ផលិតពីកាបូនសុទ្ធ ទម្ងន់ស្រាល 10kg ...
# 38  Hello\n- giant reign SX 2021\n- Condition. 99%...
# 39  កង់ទិញថ្មីនៅស្អាតធានាទាំងអស់តែងហើយ\nភ្លើងមុខក្...
# 40  https://www.facebook.com/111031863948940/posts...
# 41  🔥Brand New Giant XTC SLR 2 2021\nថ្មី 100%\n(N...
# 42  💡 មានចំណាប់អារម្មណ៍សូមទំនាក់ទំនង :\n☎️092 7111...
# 43  Specialized From usa\n☎️092/093 711181 tel: 01...
# 44  កង់លក់ size: L; 29inch\nគ្រឿងWL-TWoo 1x11\nបូម...
# 45  សួស្ដីបងៗ​\nអតិថិជនទាំងអស់ដែលផ្តោតសំខាន់ទៅលើទី...
# 46  កង់មួយទឹក\r(មិនទាន់ប្រើស្រុកខ្មែរ)\n(ទិញលុយសុទ...
# 47  កង់មួយទឹក\n(ទិញលុយសុទ្ធ ឬបង់រំលោះ100%)\nKTM\nS...
# 48  កង់ថ្មី ណាស់ មិនសូវដែលជិះ ថ្មីដូចបកកេស\nទើបតែថ...
# 49                      ស្រាល ស្រួលជិះ tel: 085999947
#
#                               Phone          Location    Price
# 0                         092510051        Phnom Penh     $195
# 1              0965159022,078971799        Phnom Penh     $930
# 2              0965159022,078971799        Phnom Penh     $300
# 3              0965159022,078971799        Phnom Penh     $400
# 4              0965159022,078971799        Phnom Penh     $400
# 5              0965159022,078971799        Phnom Penh     $300
# 6              0962322777,011232277        Phnom Penh   $17.85
# 7                         010545774        Phnom Penh     $420
# 8                         010545774        Phnom Penh     $195
# 9                         092510051        Phnom Penh     $165
# 10                        089992249        Phnom Penh     $450
# 11                        089992249        Phnom Penh     $450
# 12             0965556005,090648865        Phnom Penh     $225
# 13                        092510051        Phnom Penh     $150
# 14             0965556005,090648865        Phnom Penh     $225
# 15              012334510,016334511        Phnom Penh     $155
# 16                        099923266        Phnom Penh      $55
# 17                        069532828        Phnom Penh     $529
# 18                        016360029        Phnom Penh       $6
# 19                        010666012        Phnom Penh       $4
# 20                        010666012        Phnom Penh   $4,300
# 21             0966773776,085333103        Phnom Penh     $340
# 22                        078429973        Phnom Penh     $130
# 23              012919188,068318318        Phnom Penh     $155
# 24                        099984901        Phnom Penh      $10
# 25                        099984901        Phnom Penh     $180
# 26                        099984901        Phnom Penh     $180
# 27                        010688067        Phnom Penh      $13
# 28   0962313131,0766660001,03141...        Phnom Penh     $990
# 29   0962313131,0766660001,03141...        Phnom Penh     $750
# 30                        092510051        Phnom Penh     $165
# 31              068989829,017371535        Phnom Penh     $150
# 32                        086513331         Siem Reap     $160
# 33                       0962230090        Phnom Penh     $150
# 34                        010227519        Phnom Penh      $10
# 35                        010227519        Phnom Penh     $440
# 36                        010689339        Phnom Penh     $100
# 37              086407771,066611181        Phnom Penh     $690
# 38              060679679,077679679        Phnom Penh   $2,050
# 39              087448044,085448044      Kampong Speu     $200
# 40             0965848017,017485348        Phnom Penh   $1,120
# 41             0965848017,017485348        Phnom Penh   $1,120
# 42   016493030,092711181,0937111...        Phnom Penh   $2,150
# 43   016493030,092711181,0937111...        Phnom Penh   $1,999
# 44              093999055,067555506        Phnom Penh     $300
# 45                        093688846        Phnom Penh  $390.00
# 46                        012879091        Phnom Penh   $2,500
# 47                        012879091        Phnom Penh       $1
# 48              016786478,092207092  Banteay Meanchey     $230
# 49                        085999947        Phnom Penh   $1,900

# %% [markdown]
# <hr>
# <hr>
# <hr>

# %% [markdown]
# ## Scraping all page

# %%
title = []
description = []
phone = []
location = []
price = []

for i in range(1,42):
    url = 'https://www.khmer24.com/en/c-bicycles.html?per_page=' + str(i)
    req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
    
    
    # request to website
    website = urlopen(req).read()
    
    # create soup object
    page_soup = soup(website, "html.parser")
    
    for result in results:
    
        try:
            title.append(result.find('h2', {'class':'item-title'}).get_text())
        except:
            title.append('n/a')
        try:
            description.append(result.find('p', {'class':'description truncate truncate-2'}).get_text().strip('\n'))
        except:
            description.append('n/a')
        try:
            phone.append(result.find('p', {'class':'description truncate truncate-2'}).find('i').get_text())
        except:
            phone.append('n/a')
        try:
            location.append(result.find('li').get_text())
        except:
            location.append('n/a')
        try:
            price.append(result.find('span', {'class':'price'}).get_text())
        except:
            price.append('n/a')

# %%
bicycle_data = pd.DataFrame({'Title': title, 'Description': description, 'Phone': phone, 'Location': location, 'Price': price})

bicycle_data
# Out:
#                                             Title  \
# 0                             TREK Frame Original
# 1                                 Scott scale 970
# 2                                កង់លក់ Scott sub
# 3                                    Scott gravel
# 4                                           Scott
# ...                                           ...
# 2045  កង់ជប៉ុន បូមមុខក្រោយមានច្រើនoption off road
# 2046                                 លក់ឡៃឡុងYETI
# 2047                                          KTM
# 2048                                 កង់ លក់ 230$
# 2049                     Specialized 95% for sale
#
#                                             Description  \
# 0     TREK Frame\n#ហាងកង់ចាក់អង្រែ\n> មានលក់កង់ជជុស​...
# 1     Sram SX 12លេខ ប៉ូម rockshok judy ប្រាំង Mt200 ...
# 2     កង់លក់ Scott sub M 27.5 គ្រឿង Sram X7 កង់ជុលជុ...
# 3     Scott gravel 700 X 35 9លេខ ជង្គង់ប៉ាដាង single...
# 4     Scott sub សេះស គ្រឿង sram X7 ជង្គង់ប៉ាដាងជើងប៉...
# ...                                                 ...
# 2045  សួស្ដីបងៗ​\nអតិថិជនទាំងអស់ដែលផ្តោតសំខាន់ទៅលើទី...
# 2046  កង់មួយទឹក\r(មិនទាន់ប្រើស្រុកខ្មែរ)\n(ទិញលុយសុទ...
# 2047  កង់មួយទឹក\n(ទិញលុយសុទ្ធ ឬបង់រំលោះ100%)\nKTM\nS...
# 2048  កង់ថ្មី ណាស់ មិនសូវដែលជិះ ថ្មីដូចបកកេស\nទើបតែថ...
# 2049                      ស្រាល ស្រួលជិះ tel: 085999947
#
#                           Phone          Location    Price
# 0                tel: 092510051        Phnom Penh     $195
# 1     tel: 0965159022,078971799        Phnom Penh     $930
# 2     tel: 0965159022,078971799        Phnom Penh     $300
# 3     tel: 0965159022,078971799        Phnom Penh     $400
# 4     tel: 0965159022,078971799        Phnom Penh     $400
# ...                         ...               ...      ...
# 2045             tel: 093688846        Phnom Penh  $390.00
# 2046             tel: 012879091        Phnom Penh   $2,500
# 2047             tel: 012879091        Phnom Penh       $1
# 2048   tel: 016786478,092207092  Banteay Meanchey     $230
# 2049             tel: 085999947        Phnom Penh   $1,900
#
# [2050 rows x 5 columns]

# %% [markdown]
# ## Cleaning Phone Data column

# %%
bicycle_data['Phone'] = bicycle_data['Phone'].apply(lambda x:x.strip('tel:'))

bicycle_data
# Out:
#                                             Title  \
# 0                             TREK Frame Original
# 1                                 Scott scale 970
# 2                                កង់លក់ Scott sub
# 3                                    Scott gravel
# 4                                           Scott
# ...                                           ...
# 2045  កង់ជប៉ុន បូមមុខក្រោយមានច្រើនoption off road
# 2046                                 លក់ឡៃឡុងYETI
# 2047                                          KTM
# 2048                                 កង់ លក់ 230$
# 2049                     Specialized 95% for sale
#
#                                             Description  \
# 0     TREK Frame\n#ហាងកង់ចាក់អង្រែ\n> មានលក់កង់ជជុស​...
# 1     Sram SX 12លេខ ប៉ូម rockshok judy ប្រាំង Mt200 ...
# 2     កង់លក់ Scott sub M 27.5 គ្រឿង Sram X7 កង់ជុលជុ...
# 3     Scott gravel 700 X 35 9លេខ ជង្គង់ប៉ាដាង single...
# 4     Scott sub សេះស គ្រឿង sram X7 ជង្គង់ប៉ាដាងជើងប៉...
# ...                                                 ...
# 2045  សួស្ដីបងៗ​\nអតិថិជនទាំងអស់ដែលផ្តោតសំខាន់ទៅលើទី...
# 2046  កង់មួយទឹក\r(មិនទាន់ប្រើស្រុកខ្មែរ)\n(ទិញលុយសុទ...
# 2047  កង់មួយទឹក\n(ទិញលុយសុទ្ធ ឬបង់រំលោះ100%)\nKTM\nS...
# 2048  កង់ថ្មី ណាស់ មិនសូវដែលជិះ ថ្មីដូចបកកេស\nទើបតែថ...
# 2049                      ស្រាល ស្រួលជិះ tel: 085999947
#
#                       Phone          Location    Price
# 0                 092510051        Phnom Penh     $195
# 1      0965159022,078971799        Phnom Penh     $930
# 2      0965159022,078971799        Phnom Penh     $300
# 3      0965159022,078971799        Phnom Penh     $400
# 4      0965159022,078971799        Phnom Penh     $400
# ...                     ...               ...      ...
# 2045              093688846        Phnom Penh  $390.00
# 2046              012879091        Phnom Penh   $2,500
# 2047              012879091        Phnom Penh       $1
# 2048    016786478,092207092  Banteay Meanchey     $230
# 2049              085999947        Phnom Penh   $1,900
#
# [2050 rows x 5 columns]

# %% [markdown]
# # Write all data into excel

# %%
bicycle_data.to_csv('bicycle_data.csv', index=False)

# %%
bicycle_data.to_excel('bicyle_data.xlsx', index=False)

# %% [markdown]
# ## Read data from file that we have create

# %%
df = pd.read_csv(r"C:\Users\Hsophy\Downloads\bicycle_data.csv")
df
# Out:
#                                                   Title  \
# 0                                       Cannondale F300
# 1                     Panasonic MR-S vintage ( classic)
# 2                                      Groupset SRAM SX
# 3                   Trek Malin 5 2022 99% 3 Times used.
# 4                           2022 Trek Malin 5 S27.5 99%
# ...                                                 ...
# 2045  កង់លក់ប្រញាប់ Branch អាមេរិច model : Trek marl...
# 2046             លក់ឡៃឡុងROCKRIDER XC50 LTD (កង់បារាំង)
# 2047                                    CANYON LUX 2020
# 2048                                  កង់បត់តួរបស់ជប៉ុន
# 2049                             ឈ្នាន់កង់ ខ្សែរខ្ចៅតូច
#
#                                             Description                 Phone  \
# 0                             010 545774 tel: 010545774             010545774
# 1     Shimano Deore DX (3x7) រង្វង់ កង់ 26 tel: 0105...             010545774
# 2     ធ្លាប់តែប្រើ #លីប #ដេរីយ័រ #ដៃចុច និង #ច្រវ៉ាក...             092510051
# 3     450$ 99% Size S 27.5.\nTrek Malin 5 2022 tel: ...             089992249
# 4     តម្លៃ​ពិសេស​។ កង់​ថ្មី​ 99.99​ តម្លៃ​ខាង​លេី​អ...             089992249
# ...                                                 ...                   ...
# 2045  កង់លក់ប្រញាប់ Branch អាមេរិច model : Trek marl...             085622188
# 2046  កង់មួយទឹក(មិនទាន់ប្រើក្នុងស្រុកខ្មែរ)\n(ទិញលុយ...             012879091
# 2047  កង់មួយទឹក\r(មិនទាន់ប្រើស្រុកខ្មែរ)\n(ទិញលុយសុទ...             012879091
# 2048  ចង់លក់កង់ក្មេងអាយុ៤ទៅ៨ឆ្នាំជិះបានអាចបត់ដាក់គូទ...   016787849,068727719
# 2049                078627578\n016262406 tel: 016262406             016262406
#
#         Location   Price
# 0     Phnom Penh    $420
# 1     Phnom Penh    $195
# 2     Phnom Penh    $165
# 3     Phnom Penh    $450
# 4     Phnom Penh    $450
# ...          ...     ...
# 2045  Phnom Penh    $420
# 2046  Phnom Penh    $650
# 2047  Phnom Penh  $4,500
# 2048  Phnom Penh     $25
# 2049      Kandal      $5
#
# [2050 rows x 5 columns]
