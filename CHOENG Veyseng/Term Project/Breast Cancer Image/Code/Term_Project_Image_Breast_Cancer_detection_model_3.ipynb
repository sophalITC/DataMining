# %%
from google.colab import drive
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
list = ['benign', 'malignant', 'normal']
path = '/content/drive/MyDrive/Machine Learning Project/Dataset_BUSI_with_GT/'

def createDataset(path):
  n_class = 3
  x = []
  y = []
  for i in range(n_class):
    images = os.listdir(path + list[i])
    for image in images: 
      if 'mask' in image:
        continue     
      src = cv2.imread(path + list[i]  + '/' + image, cv2.IMREAD_COLOR)
      
      width = 100
      height = 100

      dsize = (width, height)
      output = cv2.resize(src, dsize)

      x.append(output)
      if(list[i] == 'normal'):
        y.append(0)
      elif(list[i] == 'benign'):
        y.append(1)
      elif(list[i] == 'malignant'):
        y.append(2)
  return x, y

x, y = createDataset(path)

# %%
print(len(y))
count_normal = sum(map(lambda e: e == 2, y))
print(count_normal)
# Out:
# 780
# 210

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[i],cmap='gray')
    plt.xlabel(y[i])
plt.show()

# %%
x, y = shuffle(x, y)

# %%
x = [a/255.0 for a in x]

# %%
x = np.array(x)
y = np.array(y)

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[i],cmap='gray')
    plt.xlabel(y[i])
plt.show()

# %%
import tensorflow as tf

from tensorflow.keras import layers, models

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.9)

# %%
print(len(x))
# Out:
# 780

# %%
model = models.Sequential()
model.add(layers.Conv2D(100, (3, 3), activation='relu', input_shape=(100, 100, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(200, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(200, (3, 3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 100)       2800
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 100)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 200)       180200
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 200)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 200)       360200
#
# =================================================================
# Total params: 543,200
# Trainable params: 543,200
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(3))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 100)       2800
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 100)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 200)       180200
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 200)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 200)       360200
#
#  flatten (Flatten)           (None, 88200)             0
#
#  dense (Dense)               (None, 64)                5644864
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 6,188,259
# Trainable params: 6,188,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=50, 
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 22/22 [==============================] - 59s 3s/step - loss: 1.0844 - accuracy: 0.5584 - val_loss: 1.3848 - val_accuracy: 0.3590
# Epoch 2/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.9350 - accuracy: 0.5812 - val_loss: 1.1419 - val_accuracy: 0.3590
# Epoch 3/50
# 22/22 [==============================] - 58s 3s/step - loss: 0.8884 - accuracy: 0.6268 - val_loss: 1.0562 - val_accuracy: 0.4359
# Epoch 4/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.7886 - accuracy: 0.6595 - val_loss: 1.0886 - val_accuracy: 0.4872
# Epoch 5/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.7287 - accuracy: 0.6880 - val_loss: 1.1527 - val_accuracy: 0.4615
# Epoch 6/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.6438 - accuracy: 0.7265 - val_loss: 0.9430 - val_accuracy: 0.5256
# Epoch 7/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.5894 - accuracy: 0.7251 - val_loss: 1.0828 - val_accuracy: 0.5000
# Epoch 8/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.4958 - accuracy: 0.7764 - val_loss: 1.0522 - val_accuracy: 0.5513
# Epoch 9/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.4075 - accuracy: 0.8419 - val_loss: 0.9735 - val_accuracy: 0.7179
# Epoch 10/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.3537 - accuracy: 0.8718 - val_loss: 1.5202 - val_accuracy: 0.6538
# Epoch 11/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.3104 - accuracy: 0.8889 - val_loss: 1.5050 - val_accuracy: 0.6923
# Epoch 12/50
# 22/22 [==============================] - 63s 3s/step - loss: 0.2196 - accuracy: 0.9174 - val_loss: 1.4251 - val_accuracy: 0.6795
# Epoch 13/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.2409 - accuracy: 0.9259 - val_loss: 1.3053 - val_accuracy: 0.6795
# Epoch 14/50
# 22/22 [==============================] - 58s 3s/step - loss: 0.1455 - accuracy: 0.9516 - val_loss: 2.0474 - val_accuracy: 0.6410
# Epoch 15/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.1232 - accuracy: 0.9672 - val_loss: 2.6076 - val_accuracy: 0.6410
# Epoch 16/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0730 - accuracy: 0.9744 - val_loss: 2.3130 - val_accuracy: 0.6667
# Epoch 17/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0567 - accuracy: 0.9786 - val_loss: 1.8566 - val_accuracy: 0.6795
# Epoch 18/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0363 - accuracy: 0.9872 - val_loss: 2.2590 - val_accuracy: 0.6923
# Epoch 19/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0417 - accuracy: 0.9886 - val_loss: 2.2816 - val_accuracy: 0.6923
# Epoch 20/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0365 - accuracy: 0.9858 - val_loss: 1.9265 - val_accuracy: 0.6795
# Epoch 21/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0287 - accuracy: 0.9872 - val_loss: 2.4557 - val_accuracy: 0.6795
# Epoch 22/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0496 - accuracy: 0.9900 - val_loss: 2.1033 - val_accuracy: 0.6410
# Epoch 23/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0367 - accuracy: 0.9915 - val_loss: 2.5449 - val_accuracy: 0.6667
# Epoch 24/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0278 - accuracy: 0.9915 - val_loss: 2.6926 - val_accuracy: 0.6795
# Epoch 25/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0354 - accuracy: 0.9915 - val_loss: 2.5112 - val_accuracy: 0.6795
# Epoch 26/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0294 - accuracy: 0.9915 - val_loss: 2.2379 - val_accuracy: 0.7051
# Epoch 27/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0275 - accuracy: 0.9929 - val_loss: 2.4885 - val_accuracy: 0.6923
# Epoch 28/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0234 - accuracy: 0.9900 - val_loss: 2.3508 - val_accuracy: 0.7051
# Epoch 29/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0121 - accuracy: 0.9915 - val_loss: 2.4743 - val_accuracy: 0.6923
# Epoch 30/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0225 - accuracy: 0.9943 - val_loss: 2.4816 - val_accuracy: 0.6923
# Epoch 31/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 2.9227 - val_accuracy: 0.6923
# Epoch 32/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0257 - accuracy: 0.9929 - val_loss: 2.5501 - val_accuracy: 0.7051
# Epoch 33/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0099 - accuracy: 0.9957 - val_loss: 2.7115 - val_accuracy: 0.6795
# Epoch 34/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0179 - accuracy: 0.9943 - val_loss: 2.5532 - val_accuracy: 0.7179
# Epoch 35/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0297 - accuracy: 0.9915 - val_loss: 1.9554 - val_accuracy: 0.7051
# Epoch 36/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0191 - accuracy: 0.9943 - val_loss: 2.3694 - val_accuracy: 0.6923
# Epoch 37/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0098 - accuracy: 0.9957 - val_loss: 2.7459 - val_accuracy: 0.7051
# Epoch 38/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0060 - accuracy: 0.9972 - val_loss: 2.5279 - val_accuracy: 0.6923
# Epoch 39/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0095 - accuracy: 0.9957 - val_loss: 2.8331 - val_accuracy: 0.7051
# Epoch 40/50
# 22/22 [==============================] - 58s 3s/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 2.2104 - val_accuracy: 0.7179
# Epoch 41/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0072 - accuracy: 0.9972 - val_loss: 2.6950 - val_accuracy: 0.7051
# Epoch 42/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 2.7869 - val_accuracy: 0.7179
# Epoch 43/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 2.5526 - val_accuracy: 0.7179
# Epoch 44/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 2.6833 - val_accuracy: 0.7051
# Epoch 45/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 2.8222 - val_accuracy: 0.7051
# Epoch 46/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0085 - accuracy: 0.9986 - val_loss: 2.7293 - val_accuracy: 0.7179
# Epoch 47/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0082 - accuracy: 0.9986 - val_loss: 2.9648 - val_accuracy: 0.6923
# Epoch 48/50
# 22/22 [==============================] - 57s 3s/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 2.0497 - val_accuracy: 0.7179
# Epoch 49/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0111 - accuracy: 0.9972 - val_loss: 2.8446 - val_accuracy: 0.7051
# Epoch 50/50
# 22/22 [==============================] - 56s 3s/step - loss: 0.0169 - accuracy: 0.9957 - val_loss: 2.1948 - val_accuracy: 0.7179

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.3, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 3/3 - 2s - loss: 2.1948 - accuracy: 0.7179 - 2s/epoch - 576ms/step

# %%
print(test_acc*100)
# Out:
# 71.79487347602844
