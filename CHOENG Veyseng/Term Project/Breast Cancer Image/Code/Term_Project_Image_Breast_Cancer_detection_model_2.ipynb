# %%
from google.colab import drive
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
list = ['benign', 'malignant', 'normal']
path = '/content/drive/MyDrive/Machine Learning Project/Dataset_BUSI_with_GT/'

def createDataset(path):
  n_class = 3
  x = []
  y = []
  for i in range(n_class):
    images = os.listdir(path + list[i])
    for image in images: 
      if 'mask' in image:
        continue     
      src = cv2.imread(path + list[i]  + '/' + image, cv2.IMREAD_COLOR)
      
      width = 100
      height = 100

      dsize = (width, height)
      output = cv2.resize(src, dsize)

      x.append(output)
      if(list[i] == 'normal'):
        y.append(0)
      elif(list[i] == 'benign'):
        y.append(1)
      elif(list[i] == 'malignant'):
        y.append(2)
  return x, y

x, y = createDataset(path)

# %%
print(len(y))
count_normal = sum(map(lambda e: e == 2, y))
print(count_normal)
# Out:
# 780
# 210

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[i],cmap='gray')
    plt.xlabel(y[i])
plt.show()

# %%
x, y = shuffle(x, y)

# %%
x = [a/255.0 for a in x]

# %%
x = np.array(x)
y = np.array(y)

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[i],cmap='gray')
    plt.xlabel(y[i])
plt.show()

# %%
import tensorflow as tf

from tensorflow.keras import layers, models

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8)

# %%
print(len(x))
# Out:
# 780

# %%
model = models.Sequential()
model.add(layers.Conv2D(100, (3, 3), activation='relu', input_shape=(100, 100, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(200, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(200, (3, 3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 98, 98, 100)       2800
#
#  max_pooling2d_2 (MaxPooling  (None, 49, 49, 100)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 47, 47, 200)       180200
#
#  max_pooling2d_3 (MaxPooling  (None, 23, 23, 200)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 21, 21, 200)       360200
#
# =================================================================
# Total params: 543,200
# Trainable params: 543,200
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(3))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 98, 98, 100)       2800
#
#  max_pooling2d_2 (MaxPooling  (None, 49, 49, 100)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 47, 47, 200)       180200
#
#  max_pooling2d_3 (MaxPooling  (None, 23, 23, 200)      0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 21, 21, 200)       360200
#
#  flatten_1 (Flatten)         (None, 88200)             0
#
#  dense_2 (Dense)             (None, 64)                5644864
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 6,188,259
# Trainable params: 6,188,259
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=50, 
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 20/20 [==============================] - 48s 2s/step - loss: 1.1616 - accuracy: 0.5272 - val_loss: 1.0033 - val_accuracy: 0.6026
# Epoch 2/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.9092 - accuracy: 0.6202 - val_loss: 1.0135 - val_accuracy: 0.5769
# Epoch 3/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.8018 - accuracy: 0.6699 - val_loss: 0.8795 - val_accuracy: 0.6026
# Epoch 4/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.6874 - accuracy: 0.7228 - val_loss: 0.8857 - val_accuracy: 0.6346
# Epoch 5/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.6214 - accuracy: 0.7628 - val_loss: 0.9455 - val_accuracy: 0.6218
# Epoch 6/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.4681 - accuracy: 0.8045 - val_loss: 0.9859 - val_accuracy: 0.6474
# Epoch 7/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.3726 - accuracy: 0.8558 - val_loss: 1.1886 - val_accuracy: 0.6346
# Epoch 8/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.2876 - accuracy: 0.8846 - val_loss: 0.9457 - val_accuracy: 0.6923
# Epoch 9/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.2356 - accuracy: 0.9054 - val_loss: 1.2306 - val_accuracy: 0.7051
# Epoch 10/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.1585 - accuracy: 0.9471 - val_loss: 1.4307 - val_accuracy: 0.6603
# Epoch 11/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.1016 - accuracy: 0.9647 - val_loss: 1.6525 - val_accuracy: 0.7244
# Epoch 12/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0668 - accuracy: 0.9840 - val_loss: 1.7555 - val_accuracy: 0.6346
# Epoch 13/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0723 - accuracy: 0.9776 - val_loss: 1.9177 - val_accuracy: 0.6859
# Epoch 14/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0776 - accuracy: 0.9728 - val_loss: 1.8341 - val_accuracy: 0.6731
# Epoch 15/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0303 - accuracy: 0.9920 - val_loss: 2.2436 - val_accuracy: 0.6667
# Epoch 16/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0414 - accuracy: 0.9904 - val_loss: 2.3874 - val_accuracy: 0.6795
# Epoch 17/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0497 - accuracy: 0.9904 - val_loss: 1.6781 - val_accuracy: 0.6731
# Epoch 18/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0366 - accuracy: 0.9952 - val_loss: 2.5620 - val_accuracy: 0.6795
# Epoch 19/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0139 - accuracy: 0.9936 - val_loss: 2.7022 - val_accuracy: 0.6731
# Epoch 20/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0236 - accuracy: 0.9952 - val_loss: 2.2509 - val_accuracy: 0.6795
# Epoch 21/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.0198 - accuracy: 0.9968 - val_loss: 2.4397 - val_accuracy: 0.6731
# Epoch 22/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 2.7805 - val_accuracy: 0.6667
# Epoch 23/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0150 - accuracy: 0.9968 - val_loss: 2.3075 - val_accuracy: 0.6538
# Epoch 24/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 2.2054 - val_accuracy: 0.6923
# Epoch 25/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 2.4522 - val_accuracy: 0.6603
# Epoch 26/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0132 - accuracy: 0.9952 - val_loss: 2.3388 - val_accuracy: 0.6667
# Epoch 27/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0139 - accuracy: 0.9968 - val_loss: 2.2136 - val_accuracy: 0.6667
# Epoch 28/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0082 - accuracy: 0.9968 - val_loss: 2.3886 - val_accuracy: 0.6538
# Epoch 29/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 2.3471 - val_accuracy: 0.6795
# Epoch 30/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0142 - accuracy: 0.9952 - val_loss: 2.3775 - val_accuracy: 0.6667
# Epoch 31/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0139 - accuracy: 0.9968 - val_loss: 2.0734 - val_accuracy: 0.6731
# Epoch 32/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 2.3964 - val_accuracy: 0.6795
# Epoch 33/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 2.5589 - val_accuracy: 0.6731
# Epoch 34/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 2.5538 - val_accuracy: 0.6795
# Epoch 35/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 2.6213 - val_accuracy: 0.6603
# Epoch 36/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 2.4490 - val_accuracy: 0.6859
# Epoch 37/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0039 - accuracy: 0.9968 - val_loss: 2.4740 - val_accuracy: 0.6795
# Epoch 38/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 2.4661 - val_accuracy: 0.6731
# Epoch 39/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0035 - accuracy: 0.9968 - val_loss: 2.5192 - val_accuracy: 0.6795
# Epoch 40/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 2.6142 - val_accuracy: 0.6795
# Epoch 41/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 2.2113 - val_accuracy: 0.6731
# Epoch 42/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0126 - accuracy: 0.9984 - val_loss: 2.3962 - val_accuracy: 0.6795
# Epoch 43/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 2.2150 - val_accuracy: 0.6667
# Epoch 44/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0072 - accuracy: 0.9984 - val_loss: 2.4641 - val_accuracy: 0.6667
# Epoch 45/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 2.4527 - val_accuracy: 0.6731
# Epoch 46/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0052 - accuracy: 0.9968 - val_loss: 2.3553 - val_accuracy: 0.6731
# Epoch 47/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 2.6455 - val_accuracy: 0.6667
# Epoch 48/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.6743 - val_accuracy: 0.6859
# Epoch 49/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 2.3330 - val_accuracy: 0.6795
# Epoch 50/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.0031 - accuracy: 0.9984 - val_loss: 2.4937 - val_accuracy: 0.6731

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 5/5 - 3s - loss: 2.4937 - accuracy: 0.6731 - 3s/epoch - 599ms/step

# %%
print(test_acc*100)
# Out:
# 67.30769276618958
