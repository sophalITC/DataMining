# %% [markdown]
# # Introduction

# %% [raw]
# In today’s era of Big data and IoT, we are easily loaded with rich datasets having extremely high dimensions.
# In order to get insights from such high dimensional data feature selection becomes very important.
# Since some features may be irrelevant or less significant to the dependent variable so their unnecessary inclusion to the model leads to
#     -Increase in complexity of a model and makes it harder to interpret.
#     -Increase in time complexity for a model to get trained.
#     -Result in a dumb model with inaccurate or less reliable predictions.

# %% [markdown]
# # What is Feature selection?

# %% [raw]
# it It is a process of selecting the most significant and relevant features from a vast set of features in the given dataset.
# So feature selection helps find results in
#     -Training algorithm faster.
#     -Reducing the complexity of a model and making it easier to interpret.
#     -Building a sensible model with better prediction power.
#     -Reducing over-fitting by selecting the right set of features.

# %% [markdown]
# # Feature selection methods

# %% [raw]
# There are three types of feature selection techniques :
#     -Filter methods (correlation, chi-square, ANOVA, information gain etc.)
#     -Wrapper methods (forward selection, backward selection, Stepwise selection etc.)
#     -Embedded methods (LASSO, elastic NET, Ridge Regression etc.)
#     etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # How to Choose a Feature Selection Method

# %% [raw]
# Common input variable data types:
#     -Numerical Variables
#         Integer Variables.
#         Floating Point Variables.
#     -Categorical Variables.
#         Boolean Variables (dichotomous).
#         Ordinal Variables.
#         Nominal Variables.

# %%
Numerical Input, Numerical Output 
    Pearson’s correlation coefficient (linear).
    Spearman’s rank coefficient (nonlinear).
Numerical Input, Categorical Output and Categorical Input, Numerical Output 
    ANOVA correlation coefficient (linear).
    Kendall’s rank coefficient (nonlinear).
Categorical Input, Categorical Output
    Chi-Squared test (contingency tables).
    Mutual Information.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TEST

# %% [markdown]
# # Feature Importance

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
data = pd.read_csv("train.csv")
X = data.iloc[:,1:20]  #independent columns
y = data.iloc[:,-1]    #target column i.e price range
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.02236045 0.03876749 0.02281185 0.03732524 0.01922613 0.04014928
#  0.03813505 0.0407282  0.03933308 0.03874447 0.05094518 0.05155587
#  0.38463599 0.03814427 0.04001499 0.04016063 0.01516866 0.01906088
#  0.02273232]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
